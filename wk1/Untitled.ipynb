# %%
import numpy as np
import networkx as nx
# %matplotlib inline

# %%
edge_list = np.loadtxt('SCC.txt')

# %%
H = nx.read_edgelist('SCC.txt', create_using = nx.DiGraph())

# %%
comps = nx.strongly_connected_components(H)

# %%
[len(c) for c in sorted(comps, key=len, reverse=True)]
# Out:
# [434821,
#  968,
#  459,
#  313,
#  211,
#  205,
#  197,
#  177,
#  162,
#  152,
#  149,
#  146,
#  138,
#  125,
#  122,
#  112,
#  102,
#  102,
#  101,
#  97,
#  96,
#  93,
#  90,
#  85,
#  81,
#  78,
#  78,
#  77,
#  77,
#  77,
#  75,
#  73,
#  72,
#  72,
#  72,
#  71,
#  71,
#  70,
#  69,
#  69,
#  68,
#  68,
#  68,
#  67,
#  67,
#  66,
#  65,
#  65,
#  64,
#  64,
#  63,
#  63,
#  59,
#  59,
#  59,
#  59,
#  59,
#  58,
#  58,
#  56,
#  56,
#  56,
#  55,
#  55,
#  55,
#  55,
#  55,
#  55,
#  54,
#  54,
#  54,
#  53,
#  53,
#  53,
#  53,
#  52,
#  52,
#  51,
#  51,
#  51,
#  51,
#  51,
#  49,
#  49,
#  49,
#  48,
#  48,
#  48,
#  48,
#  47,
#  47,
#  47,
#  46,
#  45,
#  45,
#  45,
#  45,
#  45,
#  45,
#  45,
#  44,
#  44,
#  44,
#  44,
#  43,
#  43,
#  43,
#  43,
#  43,
#  42,
#  42,
#  41,
#  41,
#  41,
#  41,
#  41,
#  40,
#  40,
#  40,
#  40,
#  40,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  39,
#  38,
#  38,
#  38,
#  38,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
#  37,
# ...

# %%
for i in range(2):
    comps

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-eab3e3fcc089> in <module>()
# ----> 1 comps.tolist()
#
# AttributeError: 'generator' object has no attribute 'tolist'
